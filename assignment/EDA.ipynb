# %%
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
gift = pd.read_csv('ForeignGifts_edu.csv')
sns.histplot(data=gift, x = "Foreign Gift Amount", bins = 9)
# Out:
# <Axes: xlabel='Foreign Gift Amount', ylabel='Count'>

# %%
sns.histplot(data=gift, x = "Gift Type")
# Out:
# <Axes: xlabel='Gift Type', ylabel='Count'>

# %%
gift["Gift Type"].value_counts()/(gift.shape[0])
#28221 observations, 10 variables
# Out:
# Contract         0.612097
# Monetary Gift    0.387513
# Real Estate      0.000390
# Name: Gift Type, dtype: float64

# %% [markdown]
# 61.2% of gifts are contracts
# 38.75% of gifts are monetary
# .04% of gifts are real estate

# %%
sns.kdeplot(data=gift["Foreign Gift Amount"])
# Out:
# <Axes: xlabel='Foreign Gift Amount', ylabel='Density'>

# %%
sns.kdeplot(data=gift, x ="Foreign Gift Amount",hue="Gift Type",fill=True)
# Out:
# <Axes: xlabel='Foreign Gift Amount', ylabel='Density'>

# %%
grouped_df = gift.groupby(['Country of Giftor']).count().reset_index()
grouped_df = grouped_df.sort_values(by="ID", ascending = False)
grouped_df.head(15)
# Out:
#     Country of Giftor    ID  OPEID  Institution Name  City  State  \
# 43            ENGLAND  3655   3655              3655  3655   3655
# 30              CHINA  2461   2461              2461  2461   2461
# 26             CANADA  2344   2344              2344  2344   2344
# 70              JAPAN  1896   1896              1896  1896   1896
# 132       SWITZERLAND  1676   1676              1676  1676   1676
# 118      SAUDI ARABIA  1610   1610              1610  1610   1610
# 47             FRANCE  1437   1437              1437  1437   1437
# 49            GERMANY  1394   1394              1394  1394   1394
# 58          HONG KONG  1080   1080              1080  1080   1080
# 126       SOUTH KOREA   811    811               811   811    811
# 114             QATAR   693    693               693   693    693
# 137   THE NETHERLANDS   512    512               512   512    512
# 75              KOREA   452    452               452   452    452
# ...

# %%
grouped_df = gift.groupby(['Country of Giftor']).count().reset_index()
grouped_df = grouped_df.sort_values(by="Foreign Gift Amount", ascending = False)
grouped_df.head(15)
# Out:
#     Country of Giftor    ID  OPEID  Institution Name  City  State  \
# 43            ENGLAND  3655   3655              3655  3655   3655
# 30              CHINA  2461   2461              2461  2461   2461
# 26             CANADA  2344   2344              2344  2344   2344
# 70              JAPAN  1896   1896              1896  1896   1896
# 132       SWITZERLAND  1676   1676              1676  1676   1676
# 118      SAUDI ARABIA  1610   1610              1610  1610   1610
# 47             FRANCE  1437   1437              1437  1437   1437
# 49            GERMANY  1394   1394              1394  1394   1394
# 58          HONG KONG  1080   1080              1080  1080   1080
# 126       SOUTH KOREA   811    811               811   811    811
# 114             QATAR   693    693               693   693    693
# 137   THE NETHERLANDS   512    512               512   512    512
# 75              KOREA   452    452               452   452    452
# ...

# %%
grouped_df = gift.groupby(['Institution Name']).count().reset_index()
grouped_df = grouped_df.sort_values(by="Foreign Gift Amount", ascending = False)
grouped_df.head(15)
# Out:
#                                 Institution Name    ID  OPEID  City  State  \
# 200        University of California, Los Angeles  3916   3916  3916   3916
# 29            California Institute of Technology  2502   2502  2502   2502
# 59   Columbia University in the City of New York  1127   1127  1127   1127
# 147                  Ohio State University (The)  1014   1014  1014   1014
# 99                      Johns Hopkins University   899    899   899    899
# 238           University of Michigan - Ann Arbor   715    715   715    715
# 179                          Stanford University   668    668   668    668
# 62                            Cornell University   653    653   653    653
# 259                   University of Pennsylvania   625    625   625    625
# 114        Massachusetts Institute of Technology   582    582   582    582
# 315                              Yale University   550    550   550    550
# ...

# %%
drill = pd.read_csv("drilling_rigs.csv")

# %%
drill.shape
# Out:
# (623, 10)

# %% [markdown]
# 623 observations, 10 variables
# Most of the data is correct, any variable that has missing values will have to have those values removed and replaced with a 0. Those values will have to be typecast as an int (natural gas rotary rig,crude oil rotary rigs, crude oil rotary rigs,crude oil and natural gas rotary rigs, etc).The first two are the only ones that don'tneed to be cleaned. Month as hinted in part 2 needs to be cleaned

# %%
drill_clean = drill.replace("Not Available",0)
drill_clean.astype({col: int for col in drill_clean.columns[1:]})
drill_clean.head(15)
# Out:
#              Month  \
# 0     1973 January
# 1    1973 February
# 2       1973 March
# 3       1973 April
# 4         1973 May
# 5        1973 June
# 6        1973 July
# 7      1973 August
# 8   1973 September
# 9     1973 October
# 10   1973 November
# 11   1973 December
# 12    1974 January
# 13   1974 February
# 14      1974 March
#
#     Crude Oil and Natural Gas Rotary Rigs in Operation, Onshore (Number of Rigs)  \
# 0                                                1120
# 1                                                1037
# 2                                                 959
# 3                                                 914
# 4                                                 974
# 5                                                1042
# 6                                                1075
# 7                                                1140
# 8                                                1183
# 9                                                1250
# ...

# %%
drill_clean["time"] = pd.to_datetime(drill_clean['Month'], format='%Y %B')

# %%
sns.lineplot(data=drill_clean, x = "Active Well Service Rig Count (Number of Rigs)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 sns.lineplot(data=drill_clean, x = "Active Well Service Rig Count (Number of Rigs)")
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/relational.py:638, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     635 if not p.has_xy_data:
#     636     return ax
# --> 638 p._attach(ax)
#     640 # Other functions have color as an explicit param,
#     641 # and we should probably do that here too
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1262, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
# ...
